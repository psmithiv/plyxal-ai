# %% [markdown]
# # configuare base/poetry environment

# %%
# confirm python and pip versions
# !python --version
# !pip3 --version
# Out:
# Python 3.10.6
# pip 23.2.1 from /opt/conda/lib/python3.10/site-packages/pip (python 3.10)

# %% [raw]
# # update python if necessary
# sudo apt update
# sudo apt upgrade python3
# !pip3 install --upgrade pip

# %% [raw]
# # re-confirm python and pip versions
# !python --version
# !pip3 --version

# %%
# install poetry
# !pip3 install -q poetry --use-deprecated=legacy-resolver --root-user-action=ignore

# %%
# create virtual environment and install dependancies
# !poetry install --no-root

# %%
# confirm we are using the virtual environment instance
# !poetry env list

# %% [markdown]
# ## utils

# %%
# remove all virtual environments
# !poetry env remove --all
# Out:
# Deleted virtualenv: /venv/virtualenvs/plyxalai-eJU141UF-py3.10

# %% [raw]
# # install older version of torchvision to avoid defect that causes peotry to delete a lib
# !poetry add torchvision==0.15.1

# %% [raw]
# # remove current virtual environment
# !poetry env remove 3.10.6

# %% [raw]
# # add lib
# !poetry add matplotlib_inline

# %% [raw]
# # remove all models
# !rm ./mdoel -r

# %%
# clear cache
# !pip cache purge
# !pip3 cache dir
# !rm -rf ~/.cache/pypoetry
# !rm -rf /qwen
# Out:
# WARNING: No matching packages
# Files removed: 0
# /root/.cache/pip

# %% [markdown]
# # launch application

# %%
# launch qwevl.python
# !poetry run python /root/plyxal-ai/plyxalai/src/qwenvl/qwenvl.py --cpu-only --share --server-port=2222 --model-cache="/models/qwen"

# %%
# new entry point
from plyxal_ai import PlyxalAi

plyxalai = PlyxalAi(message='hello, how are you today?')

# %%
# !poetry add install huggingface_hub["cli"]
# Out:
# Using version ^1.3.5 for install
# Using version ^0.17.1 for huggingface-hub
#
# Updating dependencies
# Resolving dependencies... (8.4s)Resolving dependencies... (1.6s)Resolving dependencies... (3.1s)
#
# Package operations: 125 installs, 1 update, 0 removals
#
#   • Installing attrs (23.1.0): Pending...
#   • Installing attrs (23.1.0): Installing...
#   • Installing attrs (23.1.0)
#   • Installing exceptiongroup (1.1.3): Pending...
#   • Installing exceptiongroup (1.1.3): Installing...
#   • Installing exceptiongroup (1.1.3)
#   • Installing frozenlist (1.4.0): Pending...
#   • Installing frozenlist (1.4.0): Installing...
#   • Installing frozenlist (1.4.0)
#   • Installing idna (3.4): Pending...
#   • Installing idna (3.4): Installing...
#   • Installing idna (3.4)
#   • Installing multidict (6.0.4): Pending...
#   • Installing multidict (6.0.4): Installing...
#   • Installing multidict (6.0.4)
#   • Installing rpds-py (0.10.2): Pending...
#   • Installing rpds-py (0.10.2): Installing...
#   • Installing rpds-py (0.10.2)
#   • Installing sniffio (1.3.0): Pending...
#   • Installing sniffio (1.3.0): Installing...
#   • Installing sniffio (1.3.0)
#   • Installing aiosignal (1.3.1): Pending...
#   • Installing aiosignal (1.3.1): Installing...
#   • Installing aiosignal (1.3.1)
#   • Installing anyio (3.7.1): Pending...
#   • Installing anyio (3.7.1): Installing...
#   • Installing anyio (3.7.1)
#   • Installing async-timeout (4.0.3): Pending...
#   • Installing async-timeout (4.0.3): Installing...
#   • Installing async-timeout (4.0.3)
#   • Installing certifi (2023.7.22): Pending...
#   • Installing certifi (2023.7.22): Installing...
#   • Installing certifi (2023.7.22)
#   • Installing charset-normalizer (3.2.0): Pending...
#   • Installing charset-normalizer (3.2.0): Installing...
#   • Installing charset-normalizer (3.2.0)
#   • Installing h11 (0.14.0): Pending...
#   • Installing h11 (0.14.0): Installing...
#   • Installing h11 (0.14.0)
#   • Installing pyasn1 (0.5.0): Pending...
#   • Installing pyasn1 (0.5.0): Installing...
#   • Installing pyasn1 (0.5.0)
#   • Installing referencing (0.30.2): Pending...
#   • Installing referencing (0.30.2): Installing...
#   • Installing referencing (0.30.2)
#   • Installing six (1.16.0): Pending...
#   • Installing six (1.16.0): Installing...
#   • Installing six (1.16.0)
#   • Installing typing-extensions (4.7.1): Pending...
#   • Installing typing-extensions (4.7.1): Installing...
#   • Installing typing-extensions (4.7.1)
#   • Installing urllib3 (1.26.16): Pending...
#   • Installing urllib3 (1.26.16): Installing...
#   • Installing urllib3 (1.26.16)
#   • Installing yarl (1.9.2): Pending...
#   • Installing yarl (1.9.2): Installing...
#   • Installing yarl (1.9.2)
#   • Installing aiohttp (3.8.5): Pending...
#   • Installing aiohttp (3.8.5): Installing...
#   • Installing aiohttp (3.8.5)
#   • Installing annotated-types (0.5.0): Pending...
#   • Installing annotated-types (0.5.0): Installing...
#   • Installing annotated-types (0.5.0)
#   • Installing cachetools (5.3.1): Pending...
#   • Installing cachetools (5.3.1): Installing...
#   • Installing cachetools (5.3.1)
#   • Installing cmake (3.27.4.1): Pending...
#   • Installing cmake (3.27.4.1): Installing...
#   • Installing cmake (3.27.4.1)
#   • Installing dill (0.3.7): Pending...
#   • Installing dill (0.3.7): Installing...
#   • Installing dill (0.3.7)
#   • Installing filelock (3.12.3): Pending...
#   • Installing filelock (3.12.3): Installing...
#   • Installing filelock (3.12.3)
#   • Installing fsspec (2023.6.0): Pending...
#   • Installing fsspec (2023.6.0): Installing...
#   • Installing fsspec (2023.6.0)
#   • Installing httpcore (0.18.0): Pending...
#   • Installing httpcore (0.18.0): Installing...
#   • Installing httpcore (0.18.0)
#   • Installing jsonschema-specifications (2023.7.1): Pending...
#   • Installing jsonschema-specifications (2023.7.1): Installing...
#   • Installing jsonschema-specifications (2023.7.1)
#   • Installing lit (16.0.6): Pending...
#   • Installing lit (16.0.6): Installing...
#   • Installing lit (16.0.6)
#   • Installing markupsafe (2.1.3): Pending...
#   • Installing markupsafe (2.1.3): Installing...
#   • Installing markupsafe (2.1.3)
#   • Installing mpmath (1.3.0): Pending...
#   • Installing mpmath (1.3.0): Installing...
#   • Installing mpmath (1.3.0)
#   • Installing numpy (1.25.2): Pending...
#   • Installing numpy (1.25.2): Installing...
#   • Installing numpy (1.25.2)
#   • Installing oauthlib (3.2.2): Pending...
#   • Installing oauthlib (3.2.2): Installing...
#   • Installing oauthlib (3.2.2)
#   • Installing packaging (23.1): Pending...
#   • Installing packaging (23.1): Installing...
#   • Installing packaging (23.1)
#   • Installing pyasn1-modules (0.3.0): Pending...
#   • Installing pyasn1-modules (0.3.0): Installing...
#   • Installing pyasn1-modules (0.3.0)
#   • Installing pydantic-core (2.6.3): Pending...
#   • Installing pydantic-core (2.6.3): Installing...
#   • Installing pydantic-core (2.6.3)
#   • Installing python-dateutil (2.8.2): Pending...
#   • Installing python-dateutil (2.8.2): Installing...
#   • Installing python-dateutil (2.8.2)
#   • Installing pytz (2023.3.post1): Pending...
#   • Installing pytz (2023.3.post1): Installing...
#   • Installing pytz (2023.3.post1)
#   • Installing pyyaml (6.0.1): Pending...
#   • Installing pyyaml (6.0.1): Installing...
#   • Installing pyyaml (6.0.1)
#   • Installing requests (2.31.0): Pending...
#   • Installing requests (2.31.0): Installing...
#   • Installing requests (2.31.0)
#   • Installing rsa (4.9): Pending...
#   • Installing rsa (4.9): Installing...
#   • Installing rsa (4.9)
#   • Updating setuptools (68.2.0 -> 68.2.1): Pending...
#   • Updating setuptools (68.2.0 -> 68.2.1): Installing...
#   • Updating setuptools (68.2.0 -> 68.2.1)
#   • Installing tomli (2.0.1): Pending...
#   • Installing tomli (2.0.1): Installing...
#   • Installing tomli (2.0.1)
#   • Installing tqdm (4.66.1): Pending...
#   • Installing tqdm (4.66.1): Installing...
#   • Installing tqdm (4.66.1)
#   • Installing tzdata (2023.3): Pending...
#   • Installing tzdata (2023.3): Installing...
#   • Installing tzdata (2023.3)
#   • Installing wcwidth (0.2.6): Pending...
#   • Installing wcwidth (0.2.6): Downloading... 0%
#   • Installing wcwidth (0.2.6): Downloading... 100%
#   • Installing wcwidth (0.2.6): Installing...
#   • Installing wcwidth (0.2.6)
#   • Installing click (8.1.7): Pending...
#   • Installing click (8.1.7): Installing...
#   • Installing click (8.1.7)
#   • Installing contourpy (1.1.0): Pending...
#   • Installing contourpy (1.1.0): Installing...
#   • Installing contourpy (1.1.0)
#   • Installing cycler (0.11.0): Pending...
#   • Installing cycler (0.11.0): Installing...
#   • Installing cycler (0.11.0)
#   • Installing fonttools (4.42.1): Pending...
#   • Installing fonttools (4.42.1): Installing...
#   • Installing fonttools (4.42.1)
#   • Installing google-auth (2.23.0): Pending...
#   • Installing google-auth (2.23.0): Installing...
#   • Installing google-auth (2.23.0)
#   • Installing httpx (0.25.0): Pending...
#   • Installing httpx (0.25.0): Installing...
#   • Installing httpx (0.25.0)
#   • Installing huggingface-hub (0.17.1): Pending...
#   • Installing huggingface-hub (0.17.1): Installing...
#   • Installing huggingface-hub (0.17.1)
#   • Installing humanfriendly (10.0): Pending...
#   • Installing humanfriendly (10.0): Installing...
#   • Installing humanfriendly (10.0)
#   • Installing jinja2 (3.1.2): Pending...
#   • Installing jinja2 (3.1.2): Installing...
#   • Installing jinja2 (3.1.2)
#   • Installing jsonschema (4.19.0): Pending...
#   • Installing jsonschema (4.19.0): Installing...
#   • Installing jsonschema (4.19.0)
#   • Installing kiwisolver (1.4.5): Pending...
#   • Installing kiwisolver (1.4.5): Installing...
#   • Installing kiwisolver (1.4.5)
#   • Installing multiprocess (0.70.15): Pending...
#   • Installing multiprocess (0.70.15): Installing...
#   • Installing multiprocess (0.70.15)
#   • Installing networkx (3.1): Pending...
#   • Installing networkx (3.1): Installing...
#   • Installing networkx (3.1)
#   • Installing nvidia-cublas-cu11 (11.10.3.66): Pending...
#   • Installing nvidia-cublas-cu11 (11.10.3.66): Installing...
#   • Installing nvidia-cublas-cu11 (11.10.3.66)
#   • Installing nvidia-cuda-cupti-cu11 (11.7.101): Pending...
#   • Installing nvidia-cuda-cupti-cu11 (11.7.101): Installing...
#   • Installing nvidia-cuda-cupti-cu11 (11.7.101)
#   • Installing nvidia-cuda-nvrtc-cu11 (11.7.99): Pending...
#   • Installing nvidia-cuda-nvrtc-cu11 (11.7.99): Installing...
#   • Installing nvidia-cuda-nvrtc-cu11 (11.7.99)
#   • Installing nvidia-cuda-runtime-cu11 (11.7.99): Pending...
#   • Installing nvidia-cuda-runtime-cu11 (11.7.99): Installing...
#   • Installing nvidia-cuda-runtime-cu11 (11.7.99)
#   • Installing nvidia-cudnn-cu11 (8.5.0.96): Pending...
#   • Installing nvidia-cudnn-cu11 (8.5.0.96): Installing...
#   • Installing nvidia-cudnn-cu11 (8.5.0.96)
#   • Installing nvidia-cufft-cu11 (10.9.0.58): Pending...
#   • Installing nvidia-cufft-cu11 (10.9.0.58): Installing...
#   • Installing nvidia-cufft-cu11 (10.9.0.58)
#   • Installing nvidia-curand-cu11 (10.2.10.91): Pending...
#   • Installing nvidia-curand-cu11 (10.2.10.91): Installing...
#   • Installing nvidia-curand-cu11 (10.2.10.91)
#   • Installing nvidia-cusolver-cu11 (11.4.0.1): Pending...
#   • Installing nvidia-cusolver-cu11 (11.4.0.1): Installing...
#   • Installing nvidia-cusolver-cu11 (11.4.0.1): Failed
#
#   OSError
#
#   [Errno 28] No space left on device
#
#   at /opt/conda/lib/python3.10/site-packages/installer/utils.py:140 in copyfileobj_with_hashing
#       136│         buf = source.read(_COPY_BUFSIZE)
#       137│         if not buf:
#       138│             break
#       139│         hasher.update(buf)
#     → 140│         dest.write(buf)
#       141│         size += len(buf)
#       142│
#       143│     return base64.urlsafe_b64encode(hasher.digest()).decode("ascii").rstrip("="), size
#       144│
#
#   • Installing nvidia-cusparse-cu11 (11.7.4.91): Pending...
#   • Installing nvidia-cusparse-cu11 (11.7.4.91): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for nvidia-cusparse-cu11 (11.7.4.91)
#
#   at /opt/conda/lib/python3.10/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing nvidia-nccl-cu11 (2.14.3): Pending...
#   • Installing nvidia-nccl-cu11 (2.14.3): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for nvidia-nccl-cu11 (2.14.3)
#
#   at /opt/conda/lib/python3.10/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing nvidia-nvtx-cu11 (11.7.91): Pending...
#   • Installing nvidia-nvtx-cu11 (11.7.91): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for nvidia-nvtx-cu11 (11.7.91)
#
#   at /opt/conda/lib/python3.10/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing pandas (2.1.0): Pending...
#   • Installing pandas (2.1.0): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pandas (2.1.0)
#
#   at /opt/conda/lib/python3.10/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing pfzy (0.3.4): Pending...
#   • Installing pfzy (0.3.4): Failed
#
#   OSError
#
#   [Errno 122] Disk quota exceeded: '/tmp/tmplkjr7bha'
#
#   at /opt/conda/lib/python3.10/tempfile.py:256 in _mkstemp_inner
#       252│         name = next(names)
#       253│         file = _os.path.join(dir, pre + name + suf)
#       254│         _sys.audit("tempfile.mkstemp", file)
#       255│         try:
#     → 256│             fd = _os.open(file, flags, 0o600)
#       257│         except FileExistsError:
#       258│             continue    # try again
#       259│         except PermissionError:
#       260│             # This exception is thrown when a directory with the chosen name
#
#   • Installing pillow (10.0.0): Pending...
#   • Installing pillow (10.0.0): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pillow (10.0.0)
#
#   at /opt/conda/lib/python3.10/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing prompt-toolkit (3.0.39): Pending...
#   • Installing prompt-toolkit (3.0.39): Failed
#
#   OSError
#
#   [Errno 122] Disk quota exceeded: '/tmp/tmpoyu8p30i'
#
#   at /opt/conda/lib/python3.10/tempfile.py:256 in _mkstemp_inner
#       252│         name = next(names)
#       253│         file = _os.path.join(dir, pre + name + suf)
#       254│         _sys.audit("tempfile.mkstemp", file)
#       255│         try:
#     → 256│             fd = _os.open(file, flags, 0o600)
#       257│         except FileExistsError:
#       258│             continue    # try again
#       259│         except PermissionError:
#       260│             # This exception is thrown when a directory with the chosen name
#
#   • Installing protobuf (4.24.3): Pending...
#   • Installing protobuf (4.24.3): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for protobuf (4.24.3)
#
#   at /opt/conda/lib/python3.10/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing pyarrow (13.0.0): Pending...
#   • Installing pyarrow (13.0.0): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pyarrow (13.0.0)
#
#   at /opt/conda/lib/python3.10/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing pydantic (2.3.0): Pending...
#   • Installing pydantic (2.3.0): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pydantic (2.3.0)
#
#   at /opt/conda/lib/python3.10/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing pyparsing (3.1.1): Pending...
#   • Installing pyparsing (3.1.1): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for pyparsing (3.1.1)
#
#   at /opt/conda/lib/python3.10/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing regex (2023.8.8): Pending...
#   • Installing regex (2023.8.8): Installing...
#   • Installing regex (2023.8.8): Failed
#
#   OSError
#
#   [Errno 122] Disk quota exceeded: '/venv/virtualenvs/plyxalai-eJU141UF-py3.10/lib/python3.10/site-packages/regex-2023.8.8.dist-info'
#
#   at /opt/conda/lib/python3.10/pathlib.py:1175 in mkdir
#       1171│         """
#       1172│         Create a new directory at this given path.
#       1173│         """
#       1174│         try:
#     → 1175│             self._accessor.mkdir(self, mode)
#       1176│         except FileNotFoundError:
#       1177│             if not parents or self.parent == self:
#       1178│                 raise
#       1179│             self.parent.mkdir(parents=True, exist_ok=True)
#
#   • Installing requests-oauthlib (1.3.1): Pending...
#   • Installing requests-oauthlib (1.3.1): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for requests-oauthlib (1.3.1)
#
#   at /opt/conda/lib/python3.10/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing safetensors (0.3.3): Pending...
#   • Installing safetensors (0.3.3): Installing...
#   • Installing safetensors (0.3.3): Failed
#
#   OSError
#
#   [Errno 122] Disk quota exceeded: '/venv/virtualenvs/plyxalai-eJU141UF-py3.10/lib/python3.10/site-packages/safetensors-0.3.3.dist-info'
#
#   at /opt/conda/lib/python3.10/pathlib.py:1175 in mkdir
#       1171│         """
#       1172│         Create a new directory at this given path.
#       1173│         """
#       1174│         try:
#     → 1175│             self._accessor.mkdir(self, mode)
#       1176│         except FileNotFoundError:
#       1177│             if not parents or self.parent == self:
#       1178│                 raise
#       1179│             self.parent.mkdir(parents=True, exist_ok=True)
#
#   • Installing sentencepiece (0.1.99): Pending...
#   • Installing sentencepiece (0.1.99): Installing...
#   • Installing sentencepiece (0.1.99): Failed
#
#   OSError
#
#   [Errno 122] Disk quota exceeded: '/venv/virtualenvs/plyxalai-eJU141UF-py3.10/lib/python3.10/site-packages/sentencepiece-0.1.99.dist-info'
#
#   at /opt/conda/lib/python3.10/pathlib.py:1175 in mkdir
#       1171│         """
#       1172│         Create a new directory at this given path.
#       1173│         """
#       1174│         try:
#     → 1175│             self._accessor.mkdir(self, mode)
#       1176│         except FileNotFoundError:
#       1177│             if not parents or self.parent == self:
#       1178│                 raise
#       1179│             self.parent.mkdir(parents=True, exist_ok=True)
#
#   • Installing setuptools-scm (7.1.0): Pending...
#   • Installing setuptools-scm (7.1.0): Installing...
#   • Installing setuptools-scm (7.1.0): Failed
#
#   OSError
#
#   [Errno 122] Disk quota exceeded: '/venv/virtualenvs/plyxalai-eJU141UF-py3.10/lib/python3.10/site-packages/setuptools_scm'
#
#   at /opt/conda/lib/python3.10/pathlib.py:1175 in mkdir
#       1171│         """
#       1172│         Create a new directory at this given path.
#       1173│         """
#       1174│         try:
#     → 1175│             self._accessor.mkdir(self, mode)
#       1176│         except FileNotFoundError:
#       1177│             if not parents or self.parent == self:
#       1178│                 raise
#       1179│             self.parent.mkdir(parents=True, exist_ok=True)
#
#   • Installing starlette (0.27.0): Pending...
#   • Installing starlette (0.27.0): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for starlette (0.27.0)
#
#   at /opt/conda/lib/python3.10/site-packages/poetry/installation/chooser.py:73 in choose_for
#        69│
#        70│             links.append(link)
#        71│
#        72│         if not links:
#     →  73│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        74│
#        75│         # Get the best link
#        76│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        77│
#
#   • Installing sympy (1.12): Pending...
#   • Installing sympy (1.12): Installing...
#   • Installing sympy (1.12): Failed
#
#   OSError
#
#   [Errno 122] Disk quota exceeded: '/venv/virtualenvs/plyxalai-eJU141UF-py3.10/bin/isympy'
#
#   at /opt/conda/lib/python3.10/pathlib.py:1119 in open
#       1115│         the built-in open() function does.
#       1116│         """
#       1117│         if "b" not in mode:
#       1118│             encoding = io.text_encoding(encoding)
#     → 1119│         return self._accessor.open(self, mode, buffering, encoding, errors,
#       1120│                                    newline)
#       1121│
#       1122│     def read_bytes(self):
#       1123│         """
#
#   • Installing tokenizers (0.13.3): Pending...
#   • Installing tokenizers (0.13.3): Installing...
#   • Installing tokenizers (0.13.3): Failed
#
#   OSError
#
#   [Errno 122] Disk quota exceeded: '/venv/virtualenvs/plyxalai-eJU141UF-py3.10/lib/python3.10/site-packages/tokenizers-0.13.3.dist-info'
#
#   at /opt/conda/lib/python3.10/pathlib.py:1175 in mkdir
#       1171│         """
#       1172│         Create a new directory at this given path.
#       1173│         """
#       1174│         try:
#     → 1175│             self._accessor.mkdir(self, mode)
#       1176│         except FileNotFoundError:
#       1177│             if not parents or self.parent == self:
#       1178│                 raise
#       1179│             self.parent.mkdir(parents=True, exist_ok=True)
#
#   • Installing toolz (0.12.0): Pending...
#   • Installing toolz (0.12.0): Installing...
#   • Installing toolz (0.12.0): Failed
#
#   OSError
#
#   [Errno 122] Disk quota exceeded: '/venv/virtualenvs/plyxalai-eJU141UF-py3.10/lib/python3.10/site-packages/tlz'
#
#   at /opt/conda/lib/python3.10/pathlib.py:1175 in mkdir
#       1171│         """
#       1172│         Create a new directory at this given path.
#       1173│         """
#       1174│         try:
#     → 1175│             self._accessor.mkdir(self, mode)
#       1176│         except FileNotFoundError:
#       1177│             if not parents or self.parent == self:
#       1178│                 raise
#       1179│             self.parent.mkdir(parents=True, exist_ok=True)
#
#   • Installing triton (2.0.0): Pending...
#   • Installing triton (2.0.0): Installing...
#   • Installing triton (2.0.0): Failed
#
#   OSError
#
#   [Errno 122] Disk quota exceeded: '/venv/virtualenvs/plyxalai-eJU141UF-py3.10/lib/python3.10/site-packages/triton'
#
#   at /opt/conda/lib/python3.10/pathlib.py:1175 in mkdir
#       1171│         """
#       1172│         Create a new directory at this given path.
#       1173│         """
#       1174│         try:
#     → 1175│             self._accessor.mkdir(self, mode)
#       1176│         except FileNotFoundError:
#       1177│             if not parents or self.parent == self:
#       1178│                 raise
#       1179│             self.parent.mkdir(parents=True, exist_ok=True)
#
#   • Installing websockets (11.0.3): Pending...
#   • Installing websockets (11.0.3): Installing...
#   • Installing websockets (11.0.3): Failed
#
#   OSError
#
#   [Errno 122] Disk quota exceeded: '/venv/virtualenvs/plyxalai-eJU141UF-py3.10/lib/python3.10/site-packages/websockets'
#
#   at /opt/conda/lib/python3.10/pathlib.py:1175 in mkdir
#       1171│         """
#       1172│         Create a new directory at this given path.
#       1173│         """
#       1174│         try:
#     → 1175│             self._accessor.mkdir(self, mode)
#       1176│         except FileNotFoundError:
#       1177│             if not parents or self.parent == self:
#       1178│                 raise
#       1179│             self.parent.mkdir(parents=True, exist_ok=True)
#
#   • Installing xxhash (3.3.0): Pending...
#   • Installing xxhash (3.3.0): Installing...
#   • Installing xxhash (3.3.0): Failed
#
#   OSError
#
#   [Errno 122] Disk quota exceeded: '/venv/virtualenvs/plyxalai-eJU141UF-py3.10/lib/python3.10/site-packages/xxhash'
#
#   at /opt/conda/lib/python3.10/pathlib.py:1175 in mkdir
#       1171│         """
#       1172│         Create a new directory at this given path.
#       1173│         """
#       1174│         try:
#     → 1175│             self._accessor.mkdir(self, mode)
#       1176│         except FileNotFoundError:
#       1177│             if not parents or self.parent == self:
#       1178│                 raise
#       1179│             self.parent.mkdir(parents=True, exist_ok=True)
